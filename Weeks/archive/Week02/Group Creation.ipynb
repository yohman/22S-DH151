# %% [markdown]
# ## Your topics of interest

# %%
import pandas as pd

# bring in the roster
df = pd.read_csv('roster.csv')

# replace nans with empty strings
import numpy as np
df = df.replace(np.nan, '', regex=True)

df
# Out:
#                      name                                           keywords  \
# 0                 Mariana                     Climate change, social justice
# 1            Cynthia Gong    Social Justice, Urban Development, Homelessness
# 2           Christina Cha                     social justice, climate change
# 3           yvonne nguyen                        film, art, food, propaganda
# 4        Daniel Fouladian                           Disasters,climate change
# 5           Irvin Ramirez                   Social Justice, Medical Research
# 6               Evelyn Hu  world health, social justice, social media, ho...
# 7            Mariam Magdy  art, philosophy, archival work, social justice...
# 8          Alex Bezirjyan             politics, current events, conservation
# 9            Camille Wong  geopolitics, public infastructure, sport stadi...
# 10        Keona Mae Pablo           Disasters, disease, crime, social media
# 11  Edryna Ahmed Zaharani          social justice, climate change, education
# 12           Aiko Paragas                                     social justice
# 13       Jack Witherspoon               Economics, Finance, Criminal Justice
# 14             Audrey Tey  Politics, social issues, housing, transportati...
# 15         Cameron Jewett          climate change, disasters, social justice
# 16        Leonela Aguilar                   veganism, climate change, COVID
# 17               Yahaira                      social justice, climate change
# 18            Radha Patel                                     Social Justice
# 19            Yazmin Kotb                                     social justice
# 20            Annika Sial  Environmental justice, conservation, human and...
# 21   Yin Ue "Tianna" Chan    economics, healthcare, education, entertainment
# 22             Hannah Kim  Social justice, gender equality, racial justic...
# 23              Erin Kwak                     social justice, climate change
# 24        Oliver Melgrove                                   environment, art
#
#               key1                  key2                     key3  \
# 0   climate change        social justice
# 1   social justice     urban development             homelessness
# 2   social justice        climate change
# 3             film                   art                     food
# 4        disasters        climate change
# 5   social justice                health
# 6           health        social justice             social media
# 7              art            philosophy            archival work
# 8         politics        current events              environment
# 9         politics  public infastructure           sport stadiums
# 10       disasters                health                    crime
# 11  social justice        climate change                education
# 12  social justice
# 13       economics               finance                    crime
# 14        politics         social issues                  housing
# 15  climate change             disasters           social justice
# 16            food        climate change                   health
# 17  social justice        climate change
# 18  social justice
# 19  social justice
# 20     environment          conservation  human and animal rights
# 21       economics                health                education
# 22  social justice                gender  racial justice/equality
# 23  social justice        climate change
# 24     environment                   art
#
#               key4            key5 key6  Unnamed: 8
# 0
# 1
# 2
# 3       propaganda
# 4
# 5
# 6         housing
# 7   social justice          gender
# 8
# 9        taxpayers
# 10    social media
# 11
# 12
# 13
# 14  transportation  cost of living
# 15
# 16
# 17
# 18
# 19
# 20        politics         history  law  literature
# 21   entertainment
# 22           crime
# 23
# 24

# %%
# create empty list
keywords = []

# loop through rows, and key columns and append to list
for index, row in df.iterrows():
    keywords.append(row.key1.strip())
    keywords.append(row.key2.strip())
    keywords.append(row.key3.strip())
    keywords.append(row.key4.strip())
    keywords.append(row.key5.strip())
    keywords.append(row.key6.strip())

# get rid of nan's
keywords = [x for x in keywords if str(x) != '']

# put it in a dataframe
keywords = pd.DataFrame(keywords,columns=['keyword'])

# add a count 
keywords = keywords.value_counts('keyword')

# reset the table
keywords = keywords.reset_index()

# rename columns
keywords.columns = ['keyword','count']

# show the keyword counts
keywords
# Out:
#                     keyword  count
# 0            social justice     14
# 1            climate change      8
# 2                    health      5
# 3                  politics      4
# 4               environment      3
# 5                     crime      3
# 6                 disasters      3
# 7                       art      3
# 8                   housing      2
# 9                 economics      2
# 10                education      2
# 11             social media      2
# 12                     food      2
# 13                   gender      2
# 14     public infastructure      1
# 15  racial justice/equality      1
# 16            archival work      1
# 17            social issues      1
# 18           sport stadiums      1
# 19                taxpayers      1
# 20           transportation      1
# 21               propaganda      1
# 22                  history      1
# 23               philosophy      1
# 24                      law      1
# 25  human and animal rights      1
# 26             homelessness      1
# 27                  finance      1
# 28                     film      1
# 29            entertainment      1
# 30           current events      1
# 31           cost of living      1
# 32             conservation      1
# 33        urban development      1

# %%
for index_keywords,keyword in keywords.iterrows():
    print(keyword.keyword.upper())
    print('')
    for index, row in df.iterrows():
        if row.key1.strip() == keyword.keyword or row.key2.strip() == keyword.keyword or row.key3.strip() == keyword.keyword or row.key4.strip() == keyword.keyword or row.key5.strip() == keyword.keyword or row.key6.strip() == keyword.keyword:
            print('    -'+ row['name'].title())
    print('')
# Out:
# SOCIAL JUSTICE
#
#     -Mariana
#     -Cynthia Gong
#     -Christina Cha
#     -Irvin Ramirez
#     -Evelyn Hu
#     -Mariam Magdy
#     -Edryna Ahmed Zaharani
#     -Aiko Paragas
#     -Cameron Jewett
#     -Yahaira
#     -Radha Patel
#     -Yazmin Kotb
#     -Hannah Kim
#     -Erin Kwak
#
# CLIMATE CHANGE
#
#     -Mariana
#     -Christina Cha
#     -Daniel Fouladian
#     -Edryna Ahmed Zaharani
#     -Cameron Jewett
#     -Leonela Aguilar
#     -Yahaira
#     -Erin Kwak
#
# HEALTH
#
#     -Irvin Ramirez
#     -Evelyn Hu
#     -Keona Mae Pablo
#     -Leonela Aguilar
#     -Yin Ue "Tianna" Chan
#
# POLITICS
#
#     -Alex Bezirjyan
#     -Camille Wong
#     -Audrey Tey
#     -Annika Sial
#
# ENVIRONMENT
#
#     -Alex Bezirjyan
#     -Annika Sial
#     -Oliver Melgrove
#
# CRIME
#
#     -Keona Mae Pablo
#     -Jack Witherspoon
#     -Hannah Kim
#
# DISASTERS
#
#     -Daniel Fouladian
#     -Keona Mae Pablo
#     -Cameron Jewett
#
# ART
#
#     -Yvonne Nguyen
#     -Mariam Magdy
#     -Oliver Melgrove
#
# HOUSING
#
#     -Evelyn Hu
#     -Audrey Tey
#
# ECONOMICS
#
#     -Jack Witherspoon
#     -Yin Ue "Tianna" Chan
#
# EDUCATION
#
#     -Edryna Ahmed Zaharani
#     -Yin Ue "Tianna" Chan
#
# SOCIAL MEDIA
#
#     -Evelyn Hu
#     -Keona Mae Pablo
#
# FOOD
#
#     -Yvonne Nguyen
#     -Leonela Aguilar
#
# GENDER
#
#     -Mariam Magdy
#     -Hannah Kim
#
# PUBLIC INFASTRUCTURE
#
#     -Camille Wong
#
# RACIAL JUSTICE/EQUALITY
#
#     -Hannah Kim
#
# ARCHIVAL WORK
#
#     -Mariam Magdy
#
# SOCIAL ISSUES
#
#     -Audrey Tey
#
# SPORT STADIUMS
#
#     -Camille Wong
#
# TAXPAYERS
#
#     -Camille Wong
#
# TRANSPORTATION
#
#     -Audrey Tey
#
# PROPAGANDA
#
#     -Yvonne Nguyen
#
# HISTORY
#
#     -Annika Sial
#
# PHILOSOPHY
#
#     -Mariam Magdy
#
# LAW
#
#     -Annika Sial
#
# HUMAN AND ANIMAL RIGHTS
#
#     -Annika Sial
#
# HOMELESSNESS
#
#     -Cynthia Gong
#
# FINANCE
#
#     -Jack Witherspoon
#
# FILM
#
#     -Yvonne Nguyen
#
# ENTERTAINMENT
#
#     -Yin Ue "Tianna" Chan
#
# CURRENT EVENTS
#
#     -Alex Bezirjyan
#
# COST OF LIVING
#
#     -Audrey Tey
#
# CONSERVATION
#
#     -Annika Sial
#
# URBAN DEVELOPMENT
#
#     -Cynthia Gong
